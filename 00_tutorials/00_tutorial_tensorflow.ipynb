# %% [markdown]
# # 00_turorial_tensorflow

# %% [markdown]
# ## tutorials-quickstart

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test, y_test, verbose=2)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.2980 - accuracy: 0.9121
# Epoch 2/5
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.1460 - accuracy: 0.9568
# Epoch 3/5
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1088 - accuracy: 0.9667
# Epoch 4/5
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0889 - accuracy: 0.9726
# Epoch 5/5
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0769 - accuracy: 0.9760
# 10000/1 - 0s - loss: 0.0384 - accuracy: 0.9752
# [0.07629481643147301, 0.9752]

# %%
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.0.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Explore the data

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_images)
# Out:
# 60000

# %% [markdown]
# ### Preprocess the data

# %%
for i in range(10):
    plt.figure()
    plt.imshow(train_images[i])
    plt.colorbar()
    plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Build the model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
# basic layer setting
model.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.2290 - accuracy: 0.9141
# Epoch 2/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.2226 - accuracy: 0.9165
# Epoch 3/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.2176 - accuracy: 0.9176
# Epoch 4/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.2123 - accuracy: 0.9218
# Epoch 5/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.2031 - accuracy: 0.9242
# Epoch 6/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.1981 - accuracy: 0.9261
# Epoch 7/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.1933 - accuracy: 0.9277
# Epoch 8/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.1879 - accuracy: 0.9286
# Epoch 9/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1840 - accuracy: 0.9309
# Epoch 10/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1790 - accuracy: 0.9324

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.4768 - accuracy: 0.8286
# Epoch 2/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.3578 - accuracy: 0.8688
# Epoch 3/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.3234 - accuracy: 0.8803
# Epoch 4/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2998 - accuracy: 0.8876
# Epoch 5/10
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2853 - accuracy: 0.8939
# Epoch 6/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2672 - accuracy: 0.8998
# Epoch 7/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2547 - accuracy: 0.9054
# Epoch 8/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2442 - accuracy: 0.9071
# Epoch 9/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2352 - accuracy: 0.9109
# Epoch 10/10
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2238 - accuracy: 0.9143

# %% [markdown]
# ### Make Predictions

# %%
predictions = model.predict(test_images)

# %%
for j in range(5):
    max_idx = 0
    max_value = 0

    for i in range(len(class_names)):
        pd = predictions[j][i]
        if max_value < pd:
            max_value = pd
            max_idx = i

    print(class_names[max_idx])
# Out:
# Ankle boot
# Pullover
# Trouser
# Trouser
# Shirt

# %%
predictions[0]
# Out:
# array([5.3045962e-08, 1.4363471e-11, 6.2149841e-09, 1.2417125e-09,
#        7.2531404e-11, 5.1005755e-04, 2.3221187e-08, 6.0422998e-03,
#        2.5272842e-08, 9.9344748e-01], dtype=float32)

# %%
for i in range(5):
    plt.figure()
    plt.imshow(test_images[i])
    plt.colorbar()
    plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %%
# 20 epochs
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
