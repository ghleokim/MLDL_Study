# %%
import pickle

def unpickle(file):
    with open(file, 'rb') as f:
        pdict = pickle.load(f, encoding='bytes')
    return pdict

# %%
df = unpickle('clf_data/data_batch_1')

# %%
X = df[b'data']
y = df[b'labels']

# %%
X, y
# Out:
# (array([[ 59,  43,  50, ..., 140,  84,  72],
#         [154, 126, 105, ..., 139, 142, 144],
#         [255, 253, 253, ...,  83,  83,  84],
#         ...,
#         [ 71,  60,  74, ...,  68,  69,  68],
#         [250, 254, 211, ..., 215, 255, 254],
#         [ 62,  61,  60, ..., 130, 130, 131]], dtype=uint8),
#  [6,
#   9,
#   9,
#   4,
#   1,
#   1,
#   2,
#   7,
#   8,
#   3,
#   4,
#   7,
#   7,
#   2,
#   9,
#   9,
#   9,
#   3,
#   2,
#   6,
#   4,
#   3,
#   6,
#   6,
#   2,
#   6,
#   3,
#   5,
#   4,
#   0,
#   0,
#   9,
#   1,
#   3,
#   4,
#   0,
#   3,
#   7,
#   3,
#   3,
#   5,
#   2,
#   2,
#   7,
#   1,
#   1,
#   1,
#   2,
#   2,
#   0,
#   9,
#   5,
#   7,
#   9,
#   2,
#   2,
#   5,
#   2,
#   4,
#   3,
#   1,
#   1,
#   8,
#   2,
#   1,
#   1,
#   4,
#   9,
#   7,
#   8,
#   5,
#   9,
#   6,
#   7,
#   3,
#   1,
#   9,
#   0,
#   3,
#   1,
#   3,
#   5,
#   4,
#   5,
#   7,
#   7,
#   4,
#   7,
#   9,
#   4,
#   2,
#   3,
#   8,
#   0,
#   1,
#   6,
#   1,
#   1,
# ...

# %%
df2 = unpickle('clf_data/test_batch')
X_test = df[b'data']
y_test = df[b'labels']

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X,y)

# %%
clf.predict(X_test)
