# %% [markdown]
# # Classification_CNN

# %% [markdown]
# ## Method
#
# Build Convolutional Neural Network model with Tensorflow.
#
# ```
# X_train: 10000 samples * 5 times of training
# X_test: 10000 samples
#
# * used (X_test, Y_test) in validation data.
#
# batch_size: 128
# epochs: 100
# ```

# %%
import pickle

def unpickle(file):
    with open(file, 'rb') as f:
        pdict = pickle.load(f, encoding='bytes')
    return pdict

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# import metadata
metadata = unpickle('clf_data/batches.meta')
labels = metadata[b'label_names']
print(labels)
# Out:
# [b'airplane', b'automobile', b'bird', b'cat', b'deer', b'dog', b'frog', b'horse', b'ship', b'truck']

# %%
# import train batch
dataset = unpickle('clf_data/data_batch_1')

X_train = [dataset[b'data']]
y_train = [dataset[b'labels']]

for i in range(2,6):
    batch = unpickle(f'clf_data/data_batch_{i}')
    batch_X = batch[b'data']
    batch_y = batch[b'labels']
    
    X_train.append(batch_X)
    y_train.append(batch_y)

[_.shape for _ in X_train]
# Out:
# [(10000, 3072), (10000, 3072), (10000, 3072), (10000, 3072), (10000, 3072)]

# %%
# import test batch
dataset_test = unpickle('clf_data/test_batch')

X_test = dataset_test[b'data']
y_test = dataset_test[b'labels']

X_test.shape, len(y_test)
# Out:
# ((10000, 3072), 10000)

# %%
X_train = [_batch / 255.0 for _batch in X_train]
X_test = X_test / 255.0
X_train[0][0]
# Out:
# array([0.23137255, 0.16862745, 0.19607843, ..., 0.54901961, 0.32941176,
#        0.28235294])

# %% [markdown]
# ## Data categorize / reshape

# %%
import tensorflow as tf

# %%
from keras.utils import np_utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Convolution2D, MaxPooling2D, Flatten, Convolution3D, Reshape

# %%
output_dim = nb_classes = 10

# %%
input_dim = (32,32,3)
X_train = [_batch.reshape(10000, *input_dim) for _batch in X_train]
X_test = X_test.reshape(10000, *input_dim)

[_.shape for _ in X_train]
# Out:
# [(10000, 32, 32, 3),
#  (10000, 32, 32, 3),
#  (10000, 32, 32, 3),
#  (10000, 32, 32, 3),
#  (10000, 32, 32, 3)]

# %%
X_train = [_batch.astype('float32') for _batch in X_train]
X_test = X_test.astype('float32')
Y_train = [np_utils.to_categorical(_batch, nb_classes) for _batch in y_train]
Y_test = np_utils.to_categorical(y_test, nb_classes)

# %%
input_dim, X_train[0].shape, Y_train[0].shape
# Out:
# ((32, 32, 3), (10000, 32, 32, 3), (10000, 10))

# %% [markdown]
# ## Build Model

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(64,(3,3), activation='relu', input_shape=(32,32,3)))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(64,(3,3), activation='relu'))
model.add(BatchNormalization())

model.add(Convolution2D(5,1, activation='relu'))

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))

# 14,14
model.add(Convolution2D(16,(3,3), activation='relu'))
model.add(BatchNormalization())

# 12, 12
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Convolution2D(10, 1, activation='relu'))

model.add(Convolution2D(10, 6))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dense(10))

model.add(Activation('softmax'))

model.add(Dense(output_dim, input_dim=input_dim, activation='softmax'))
batch_size=100
epochs=10

# %%
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_50 (Conv2D)           (None, 30, 30, 64)        1792
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 30, 30, 64)        256
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 28, 28, 5)         325
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 14, 14, 5)         0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 12, 12, 16)        736
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 12, 12, 16)        64
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 6, 6, 16)          0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 6, 6, 10)          170
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 1, 1, 10)          3610
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 10)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               5632
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                110
# =================================================================
# Total params: 55,009
# Trainable params: 54,721
# Non-trainable params: 288
# _________________________________________________________________

# %%
model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy','mse'])

# %%
history = []

for i in range(5):
    hist = model.fit(X_train[i], Y_train[i],
                    batch_size=batch_size, epochs=epochs,
                    verbose=1, validation_data=(X_test, Y_test))
    history.append(hist)
# Out:
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 19s 2ms/sample - loss: 2.1849 - accuracy: 0.2031 - val_loss: 2.2645 - val_accuracy: 0.1826
# Epoch 2/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 2.1114 - accuracy: 0.2422 - val_loss: 2.2384 - val_accuracy: 0.1754
# Epoch 3/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 2.0605 - accuracy: 0.2679 - val_loss: 2.2023 - val_accuracy: 0.1896
# Epoch 4/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 2.0143 - accuracy: 0.2788 - val_loss: 2.1983 - val_accuracy: 0.1829
# Epoch 5/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.9699 - accuracy: 0.3093 - val_loss: 2.0025 - val_accuracy: 0.2862
# Epoch 6/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.9267 - accuracy: 0.3245 - val_loss: 1.9537 - val_accuracy: 0.3031
# Epoch 7/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.8849 - accuracy: 0.3370 - val_loss: 1.8966 - val_accuracy: 0.3254
# Epoch 8/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.8447 - accuracy: 0.3474 - val_loss: 1.8961 - val_accuracy: 0.3162
# Epoch 9/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.8023 - accuracy: 0.3524 - val_loss: 1.8512 - val_accuracy: 0.3230
# Epoch 10/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.7684 - accuracy: 0.3596 - val_loss: 1.8517 - val_accuracy: 0.3220
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.8307 - accuracy: 0.3249 - val_loss: 1.8080 - val_accuracy: 0.3361
# Epoch 2/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.7856 - accuracy: 0.3432 - val_loss: 1.8064 - val_accuracy: 0.3315
# Epoch 3/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.7418 - accuracy: 0.3569 - val_loss: 1.7497 - val_accuracy: 0.3504
# Epoch 4/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.7083 - accuracy: 0.3698 - val_loss: 1.7291 - val_accuracy: 0.3574
# Epoch 5/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.6701 - accuracy: 0.3834 - val_loss: 1.7274 - val_accuracy: 0.3533
# Epoch 6/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.6410 - accuracy: 0.3901 - val_loss: 1.7355 - val_accuracy: 0.3458
# Epoch 7/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.6093 - accuracy: 0.4021 - val_loss: 1.6874 - val_accuracy: 0.3707
# Epoch 8/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5864 - accuracy: 0.4190 - val_loss: 1.8663 - val_accuracy: 0.3338
# Epoch 9/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5595 - accuracy: 0.4340 - val_loss: 1.6731 - val_accuracy: 0.3921
# Epoch 10/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5238 - accuracy: 0.4529 - val_loss: 1.6865 - val_accuracy: 0.3965
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.6346 - accuracy: 0.4092 - val_loss: 1.7222 - val_accuracy: 0.3796
# Epoch 2/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5741 - accuracy: 0.4331 - val_loss: 1.7540 - val_accuracy: 0.3717
# Epoch 3/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5384 - accuracy: 0.4463 - val_loss: 1.6614 - val_accuracy: 0.4028
# Epoch 4/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5000 - accuracy: 0.4665 - val_loss: 1.7644 - val_accuracy: 0.3661
# Epoch 5/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4668 - accuracy: 0.4691 - val_loss: 1.6090 - val_accuracy: 0.4160
# Epoch 6/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4372 - accuracy: 0.4745 - val_loss: 1.5867 - val_accuracy: 0.4259
# Epoch 7/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4062 - accuracy: 0.4883 - val_loss: 1.5592 - val_accuracy: 0.4324
# Epoch 8/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3839 - accuracy: 0.4978 - val_loss: 1.6611 - val_accuracy: 0.4075
# Epoch 9/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3551 - accuracy: 0.5073 - val_loss: 1.5478 - val_accuracy: 0.4432
# Epoch 10/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3309 - accuracy: 0.5092 - val_loss: 1.6170 - val_accuracy: 0.4152
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.5512 - accuracy: 0.4421 - val_loss: 1.5334 - val_accuracy: 0.4445
# Epoch 2/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4977 - accuracy: 0.4627 - val_loss: 1.6255 - val_accuracy: 0.4174
# Epoch 3/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4448 - accuracy: 0.4776 - val_loss: 1.6415 - val_accuracy: 0.4008
# Epoch 4/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4172 - accuracy: 0.4905 - val_loss: 1.5955 - val_accuracy: 0.4243
# Epoch 5/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3844 - accuracy: 0.4974 - val_loss: 1.5660 - val_accuracy: 0.4306
# Epoch 6/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3498 - accuracy: 0.5099 - val_loss: 1.5316 - val_accuracy: 0.4568
# Epoch 7/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3218 - accuracy: 0.5176 - val_loss: 1.5036 - val_accuracy: 0.4581
# Epoch 8/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.2978 - accuracy: 0.5270 - val_loss: 1.5763 - val_accuracy: 0.4411
# Epoch 9/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.2694 - accuracy: 0.5380 - val_loss: 1.5225 - val_accuracy: 0.4484
# Epoch 10/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.2469 - accuracy: 0.5458 - val_loss: 1.7763 - val_accuracy: 0.3944
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.4684 - accuracy: 0.4747 - val_loss: 1.4863 - val_accuracy: 0.4671
# Epoch 2/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3962 - accuracy: 0.5020 - val_loss: 1.4981 - val_accuracy: 0.4536
# Epoch 3/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3501 - accuracy: 0.5131 - val_loss: 1.4495 - val_accuracy: 0.4793
# Epoch 4/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.3086 - accuracy: 0.5313 - val_loss: 1.5146 - val_accuracy: 0.4559
# Epoch 5/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.2721 - accuracy: 0.5526 - val_loss: 1.5036 - val_accuracy: 0.4743
# Epoch 6/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.2412 - accuracy: 0.5590 - val_loss: 1.5650 - val_accuracy: 0.4484
# Epoch 7/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.2090 - accuracy: 0.5746 - val_loss: 1.4537 - val_accuracy: 0.4976
# Epoch 8/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.1797 - accuracy: 0.5900 - val_loss: 1.4438 - val_accuracy: 0.4997
# Epoch 9/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.1616 - accuracy: 0.5909 - val_loss: 1.4899 - val_accuracy: 0.4883
# Epoch 10/10
# 10000/10000 [==============================] - 18s 2ms/sample - loss: 1.1289 - accuracy: 0.6075 - val_loss: 1.4562 - val_accuracy: 0.4985

# %%
score = model.evaluate(X_test, Y_test, verbose=0) 
print('Test error:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test error: 1.4561574445724488
# Test accuracy: 0.4985

# %%
for i in range(len(history)):
    plt.plot(history[i].history['accuracy'],'r')
    plt.plot(history[i].history['val_accuracy'],'b')
    plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
    plt.show()

# %%
for i in range(len(history)):
    plt.plot(history[i].history['loss'],'r')
    plt.plot(history[i].history['val_loss'],'b')
    plt.legend({'training loss':'r', 'validation loss': 'b'})
    plt.show()

# %% [markdown]
# ## Inference

# %%
predictions = model.predict_classes(X_test)

# %%
# we can also use a confusion matrix to visualize the performance of a classification model
cm = confusion_matrix(y_test, predictions)
# use this line to normalize the confusion matrix to show percentages instead of counts
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
# plot this matrix
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Overall Accuracy Score: {0:.4f}'.format(score[1])
plt.title(all_sample_title, size = 15);
# plt.savefig('toy_Digits_ConfusionSeabornCodementor.png')
plt.show();
