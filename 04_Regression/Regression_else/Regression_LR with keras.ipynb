# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv('reg_data/abalone.data',
                 names=['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings'])

# %%
dummy = pd.get_dummies(df['Sex'])
dummy.head()

df = pd.concat([df.iloc[:,0], dummy, df.iloc[:,1:]], axis=1)
df.head()
# Out:
#   Sex  F  I  M  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0   M  0  0  1   0.455     0.365   0.095        0.5140          0.2245
# 1   M  0  0  1   0.350     0.265   0.090        0.2255          0.0995
# 2   F  1  0  0   0.530     0.420   0.135        0.6770          0.2565
# 3   M  0  0  1   0.440     0.365   0.125        0.5160          0.2155
# 4   I  0  1  0   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
X = df.iloc[:,1:-1].values
y = df.iloc[:, -1].values

X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.2, random_state=7)

X_tr.shape, X_te.shape, y_tr.shape, y_te.shape
# Out:
# ((3341, 10), (836, 10), (3341,), (836,))

# %%
X_tr = X_tr.astype('float32')
# X_tr.info()
y_tr = y_tr.astype('float32')
X_te = X_te.astype('float32')
y_te = y_te.astype('float32')

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
X[:5]
# Out:
# array([[0.    , 0.    , 1.    , 0.455 , 0.365 , 0.095 , 0.514 , 0.2245,
#         0.101 , 0.15  ],
#        [0.    , 0.    , 1.    , 0.35  , 0.265 , 0.09  , 0.2255, 0.0995,
#         0.0485, 0.07  ],
#        [1.    , 0.    , 0.    , 0.53  , 0.42  , 0.135 , 0.677 , 0.2565,
#         0.1415, 0.21  ],
#        [0.    , 0.    , 1.    , 0.44  , 0.365 , 0.125 , 0.516 , 0.2155,
#         0.114 , 0.155 ],
#        [0.    , 1.    , 0.    , 0.33  , 0.255 , 0.08  , 0.205 , 0.0895,
#         0.0395, 0.055 ]])

# %% [markdown]
# ## model

# %%
model = Sequential()
model.add(Dense(32, input_shape=(10,)))
model.add(Flatten())
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                352
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
batch_size=128

history = model.fit(X_tr, y_tr, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 2672 samples, validate on 669 samples
# Epoch 1/100
# 2672/2672 [==============================] - 1s 360us/sample - loss: 108.0055 - mae: 9.8700 - val_loss: 93.4926 - val_mae: 9.1714
# Epoch 2/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 90.9003 - mae: 9.0031 - val_loss: 77.8259 - val_mae: 8.3176
# Epoch 3/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 74.8836 - mae: 8.1026 - val_loss: 62.7397 - val_mae: 7.4003
# Epoch 4/100
# 2672/2672 [==============================] - 0s 39us/sample - loss: 59.3049 - mae: 7.1180 - val_loss: 48.0809 - val_mae: 6.3807
# Epoch 5/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 44.4863 - mae: 6.0311 - val_loss: 34.6546 - val_mae: 5.2722
# Epoch 6/100
# 2672/2672 [==============================] - 0s 37us/sample - loss: 31.4993 - mae: 4.8691 - val_loss: 23.4367 - val_mae: 4.1203
# Epoch 7/100
# 2672/2672 [==============================] - 0s 32us/sample - loss: 21.2503 - mae: 3.7102 - val_loss: 15.3035 - val_mae: 3.0361
# Epoch 8/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 14.3565 - mae: 2.7527 - val_loss: 10.2931 - val_mae: 2.2553
# Epoch 9/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 10.3812 - mae: 2.1799 - val_loss: 7.8270 - val_mae: 1.9013
# Epoch 10/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 8.5891 - mae: 1.9803 - val_loss: 6.8157 - val_mae: 1.7983
# Epoch 11/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 7.9131 - mae: 1.9442 - val_loss: 6.4892 - val_mae: 1.7941
# Epoch 12/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 7.6860 - mae: 1.9609 - val_loss: 6.3966 - val_mae: 1.8049
# Epoch 13/100
# 2672/2672 [==============================] - 0s 35us/sample - loss: 7.6037 - mae: 1.9733 - val_loss: 6.3582 - val_mae: 1.8106
# Epoch 14/100
# 2672/2672 [==============================] - 0s 21us/sample - loss: 7.5568 - mae: 1.9748 - val_loss: 6.3309 - val_mae: 1.8097
# Epoch 15/100
# 2672/2672 [==============================] - 0s 21us/sample - loss: 7.5145 - mae: 1.9779 - val_loss: 6.3091 - val_mae: 1.8112
# Epoch 16/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 7.4790 - mae: 1.9762 - val_loss: 6.2872 - val_mae: 1.8073
# Epoch 17/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 7.4431 - mae: 1.9734 - val_loss: 6.2686 - val_mae: 1.8052
# Epoch 18/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 7.4125 - mae: 1.9695 - val_loss: 6.2504 - val_mae: 1.8016
# Epoch 19/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 7.3804 - mae: 1.9635 - val_loss: 6.2338 - val_mae: 1.7959
# Epoch 20/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 7.3528 - mae: 1.9599 - val_loss: 6.2184 - val_mae: 1.7945
# Epoch 21/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 7.3254 - mae: 1.9574 - val_loss: 6.2048 - val_mae: 1.7929
# Epoch 22/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 7.2994 - mae: 1.9554 - val_loss: 6.1917 - val_mae: 1.7924
# Epoch 23/100
# 2672/2672 [==============================] - 0s 35us/sample - loss: 7.2749 - mae: 1.9513 - val_loss: 6.1790 - val_mae: 1.7894
# Epoch 24/100
# 2672/2672 [==============================] - 0s 33us/sample - loss: 7.2531 - mae: 1.9527 - val_loss: 6.1683 - val_mae: 1.7901
# Epoch 25/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 7.2324 - mae: 1.9436 - val_loss: 6.1553 - val_mae: 1.7804
# Epoch 26/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 7.2070 - mae: 1.9413 - val_loss: 6.1449 - val_mae: 1.7836
# Epoch 27/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 7.1879 - mae: 1.9468 - val_loss: 6.1362 - val_mae: 1.7881
# Epoch 28/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 7.1699 - mae: 1.9402 - val_loss: 6.1226 - val_mae: 1.7803
# Epoch 29/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 7.1463 - mae: 1.9397 - val_loss: 6.1116 - val_mae: 1.7790
# Epoch 30/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 7.1274 - mae: 1.9354 - val_loss: 6.1002 - val_mae: 1.7748
# Epoch 31/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 7.1094 - mae: 1.9356 - val_loss: 6.0915 - val_mae: 1.7775
# Epoch 32/100
# 2672/2672 [==============================] - 0s 36us/sample - loss: 7.0901 - mae: 1.9277 - val_loss: 6.0793 - val_mae: 1.7705
# Epoch 33/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 7.0725 - mae: 1.9308 - val_loss: 6.0703 - val_mae: 1.7739
# Epoch 34/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 7.0570 - mae: 1.9292 - val_loss: 6.0602 - val_mae: 1.7733
# Epoch 35/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 7.0402 - mae: 1.9160 - val_loss: 6.0488 - val_mae: 1.7594
# Epoch 36/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 7.0182 - mae: 1.9165 - val_loss: 6.0416 - val_mae: 1.7699
# Epoch 37/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 7.0021 - mae: 1.9206 - val_loss: 6.0292 - val_mae: 1.7642
# Epoch 38/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.9846 - mae: 1.9149 - val_loss: 6.0184 - val_mae: 1.7640
# Epoch 39/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 6.9699 - mae: 1.9122 - val_loss: 6.0088 - val_mae: 1.7602
# Epoch 40/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 6.9517 - mae: 1.9137 - val_loss: 6.0000 - val_mae: 1.7658
# Epoch 41/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 6.9366 - mae: 1.9176 - val_loss: 5.9906 - val_mae: 1.7643
# Epoch 42/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.9193 - mae: 1.9136 - val_loss: 5.9785 - val_mae: 1.7565
# Epoch 43/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 6.9059 - mae: 1.9081 - val_loss: 5.9693 - val_mae: 1.7537
# Epoch 44/100
# 2672/2672 [==============================] - 0s 38us/sample - loss: 6.8906 - mae: 1.9012 - val_loss: 5.9590 - val_mae: 1.7487
# Epoch 45/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 6.8755 - mae: 1.9011 - val_loss: 5.9524 - val_mae: 1.7563
# Epoch 46/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.8648 - mae: 1.8963 - val_loss: 5.9398 - val_mae: 1.7476
# Epoch 47/100
# 2672/2672 [==============================] - 0s 39us/sample - loss: 6.8468 - mae: 1.8988 - val_loss: 5.9357 - val_mae: 1.7543
# Epoch 48/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 6.8327 - mae: 1.9027 - val_loss: 5.9241 - val_mae: 1.7526
# Epoch 49/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 6.8183 - mae: 1.8918 - val_loss: 5.9126 - val_mae: 1.7447
# Epoch 50/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 6.8036 - mae: 1.8894 - val_loss: 5.9052 - val_mae: 1.7462
# Epoch 51/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 6.7891 - mae: 1.8952 - val_loss: 5.8983 - val_mae: 1.7520
# Epoch 52/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 6.7763 - mae: 1.8938 - val_loss: 5.8874 - val_mae: 1.7454
# Epoch 53/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 6.7648 - mae: 1.8908 - val_loss: 5.8778 - val_mae: 1.7421
# Epoch 54/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 6.7503 - mae: 1.8865 - val_loss: 5.8706 - val_mae: 1.7457
# Epoch 55/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.7375 - mae: 1.8841 - val_loss: 5.8634 - val_mae: 1.7421
# Epoch 56/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 6.7249 - mae: 1.8815 - val_loss: 5.8533 - val_mae: 1.7376
# Epoch 57/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.7104 - mae: 1.8814 - val_loss: 5.8485 - val_mae: 1.7429
# Epoch 58/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 6.6995 - mae: 1.8795 - val_loss: 5.8392 - val_mae: 1.7372
# Epoch 59/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.6916 - mae: 1.8875 - val_loss: 5.8316 - val_mae: 1.7418
# Epoch 60/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.6767 - mae: 1.8715 - val_loss: 5.8231 - val_mae: 1.7297
# Epoch 61/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 6.6626 - mae: 1.8664 - val_loss: 5.8131 - val_mae: 1.7338
# Epoch 62/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 6.6508 - mae: 1.8761 - val_loss: 5.8079 - val_mae: 1.7401
# Epoch 63/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 6.6384 - mae: 1.8808 - val_loss: 5.7995 - val_mae: 1.7394
# Epoch 64/100
# 2672/2672 [==============================] - 0s 31us/sample - loss: 6.6259 - mae: 1.8728 - val_loss: 5.7880 - val_mae: 1.7326
# Epoch 65/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 6.6144 - mae: 1.8607 - val_loss: 5.7798 - val_mae: 1.7265
# Epoch 66/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 6.6016 - mae: 1.8647 - val_loss: 5.7705 - val_mae: 1.7295
# Epoch 67/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.5909 - mae: 1.8626 - val_loss: 5.7648 - val_mae: 1.7288
# Epoch 68/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.5780 - mae: 1.8669 - val_loss: 5.7561 - val_mae: 1.7289
# Epoch 69/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.5664 - mae: 1.8610 - val_loss: 5.7458 - val_mae: 1.7213
# Epoch 70/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 6.5534 - mae: 1.8583 - val_loss: 5.7411 - val_mae: 1.7283
# Epoch 71/100
# 2672/2672 [==============================] - 0s 37us/sample - loss: 6.5424 - mae: 1.8628 - val_loss: 5.7311 - val_mae: 1.7286
# Epoch 72/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 6.5331 - mae: 1.8510 - val_loss: 5.7182 - val_mae: 1.7188
# Epoch 73/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 6.5176 - mae: 1.8555 - val_loss: 5.7122 - val_mae: 1.7225
# Epoch 74/100
# 2672/2672 [==============================] - 0s 35us/sample - loss: 6.5062 - mae: 1.8511 - val_loss: 5.7021 - val_mae: 1.7175
# Epoch 75/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 6.4952 - mae: 1.8468 - val_loss: 5.6954 - val_mae: 1.7191
# Epoch 76/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.4874 - mae: 1.8625 - val_loss: 5.6862 - val_mae: 1.7228
# Epoch 77/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 6.4720 - mae: 1.8431 - val_loss: 5.6769 - val_mae: 1.7128
# Epoch 78/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 6.4597 - mae: 1.8424 - val_loss: 5.6724 - val_mae: 1.7185
# Epoch 79/100
# 2672/2672 [==============================] - 0s 31us/sample - loss: 6.4475 - mae: 1.8458 - val_loss: 5.6562 - val_mae: 1.7096
# Epoch 80/100
# 2672/2672 [==============================] - 0s 33us/sample - loss: 6.4352 - mae: 1.8417 - val_loss: 5.6498 - val_mae: 1.7096
# Epoch 81/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 6.4291 - mae: 1.8489 - val_loss: 5.6407 - val_mae: 1.7114
# Epoch 82/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.4091 - mae: 1.8331 - val_loss: 5.6266 - val_mae: 1.7007
# Epoch 83/100
# 2672/2672 [==============================] - 0s 34us/sample - loss: 6.3994 - mae: 1.8316 - val_loss: 5.6191 - val_mae: 1.7042
# Epoch 84/100
# 2672/2672 [==============================] - 0s 59us/sample - loss: 6.3867 - mae: 1.8383 - val_loss: 5.6113 - val_mae: 1.7059
# Epoch 85/100
# 2672/2672 [==============================] - 0s 52us/sample - loss: 6.3757 - mae: 1.8294 - val_loss: 5.6009 - val_mae: 1.6961
# Epoch 86/100
# 2672/2672 [==============================] - 0s 33us/sample - loss: 6.3603 - mae: 1.8304 - val_loss: 5.5925 - val_mae: 1.7030
# Epoch 87/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 6.3490 - mae: 1.8297 - val_loss: 5.5818 - val_mae: 1.7004
# Epoch 88/100
# 2672/2672 [==============================] - 0s 56us/sample - loss: 6.3350 - mae: 1.8268 - val_loss: 5.5703 - val_mae: 1.6989
# Epoch 89/100
# 2672/2672 [==============================] - 0s 94us/sample - loss: 6.3242 - mae: 1.8237 - val_loss: 5.5599 - val_mae: 1.6956
# Epoch 90/100
# 2672/2672 [==============================] - 0s 40us/sample - loss: 6.3139 - mae: 1.8196 - val_loss: 5.5564 - val_mae: 1.7045
# Epoch 91/100
# 2672/2672 [==============================] - 0s 46us/sample - loss: 6.3012 - mae: 1.8347 - val_loss: 5.5411 - val_mae: 1.6949
# Epoch 92/100
# 2672/2672 [==============================] - 0s 54us/sample - loss: 6.2836 - mae: 1.8153 - val_loss: 5.5286 - val_mae: 1.6869
# Epoch 93/100
# 2672/2672 [==============================] - 0s 61us/sample - loss: 6.2708 - mae: 1.8117 - val_loss: 5.5214 - val_mae: 1.6933
# Epoch 94/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 6.2585 - mae: 1.8146 - val_loss: 5.5109 - val_mae: 1.6914
# Epoch 95/100
# 2672/2672 [==============================] - 0s 35us/sample - loss: 6.2460 - mae: 1.8175 - val_loss: 5.4977 - val_mae: 1.6885
# Epoch 96/100
# 2672/2672 [==============================] - 0s 51us/sample - loss: 6.2335 - mae: 1.8150 - val_loss: 5.4943 - val_mae: 1.6889
# Epoch 97/100
# 2672/2672 [==============================] - 0s 44us/sample - loss: 6.2197 - mae: 1.8043 - val_loss: 5.4746 - val_mae: 1.6780
# Epoch 98/100
# 2672/2672 [==============================] - 0s 61us/sample - loss: 6.2051 - mae: 1.8046 - val_loss: 5.4685 - val_mae: 1.6850
# Epoch 99/100
# 2672/2672 [==============================] - 0s 49us/sample - loss: 6.1938 - mae: 1.8006 - val_loss: 5.4598 - val_mae: 1.6814
# Epoch 100/100
# 2672/2672 [==============================] - 0s 68us/sample - loss: 6.1806 - mae: 1.8032 - val_loss: 5.4438 - val_mae: 1.6787

# %%
y_pred = model.predict(X_te)

# %%
score = model.evaluate(X_te, y_te, batch_size=128)
# Out:
# 836/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [6.656052112579346, 1.780649]

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model mse')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation accuracy values
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Model mae')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## model 2 increase nodes

# %%
model = Sequential()
model.add(Dense(256, input_shape=(10,)))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               2816
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 3,073
# Trainable params: 3,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
batch_size=128

history = model.fit(X_tr, y_tr, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 2672 samples, validate on 669 samples
# Epoch 1/100
# 2672/2672 [==============================] - 1s 210us/sample - loss: 91.0387 - mae: 8.9823 - val_loss: 64.0518 - val_mae: 7.4836
# Epoch 2/100
# 2672/2672 [==============================] - 0s 46us/sample - loss: 50.0047 - mae: 6.4057 - val_loss: 29.0311 - val_mae: 4.7277
# Epoch 3/100
# 2672/2672 [==============================] - 0s 44us/sample - loss: 19.7355 - mae: 3.4799 - val_loss: 9.4431 - val_mae: 2.1273
# Epoch 4/100
# 2672/2672 [==============================] - 0s 46us/sample - loss: 8.8165 - mae: 2.0613 - val_loss: 6.7077 - val_mae: 1.8888
# Epoch 5/100
# 2672/2672 [==============================] - 0s 45us/sample - loss: 8.0491 - mae: 2.1054 - val_loss: 6.6403 - val_mae: 1.8824
# Epoch 6/100
# 2672/2672 [==============================] - 0s 43us/sample - loss: 7.8511 - mae: 2.0281 - val_loss: 6.5347 - val_mae: 1.8265
# Epoch 7/100
# 2672/2672 [==============================] - 0s 34us/sample - loss: 7.7418 - mae: 1.9980 - val_loss: 6.4672 - val_mae: 1.8226
# Epoch 8/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 7.6418 - mae: 1.9941 - val_loss: 6.4025 - val_mae: 1.8196
# Epoch 9/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 7.5487 - mae: 1.9868 - val_loss: 6.3398 - val_mae: 1.8106
# Epoch 10/100
# 2672/2672 [==============================] - 0s 45us/sample - loss: 7.4572 - mae: 1.9735 - val_loss: 6.2772 - val_mae: 1.7979
# Epoch 11/100
# 2672/2672 [==============================] - 0s 41us/sample - loss: 7.3724 - mae: 1.9715 - val_loss: 6.2209 - val_mae: 1.7923
# Epoch 12/100
# 2672/2672 [==============================] - 0s 40us/sample - loss: 7.2847 - mae: 1.9543 - val_loss: 6.1627 - val_mae: 1.7822
# Epoch 13/100
# 2672/2672 [==============================] - 0s 32us/sample - loss: 7.2055 - mae: 1.9448 - val_loss: 6.1161 - val_mae: 1.7720
# Epoch 14/100
# 2672/2672 [==============================] - 0s 50us/sample - loss: 7.1299 - mae: 1.9295 - val_loss: 6.0619 - val_mae: 1.7647
# Epoch 15/100
# 2672/2672 [==============================] - 0s 41us/sample - loss: 7.0561 - mae: 1.9176 - val_loss: 6.0169 - val_mae: 1.7627
# Epoch 16/100
# 2672/2672 [==============================] - 0s 40us/sample - loss: 6.9879 - mae: 1.9181 - val_loss: 5.9726 - val_mae: 1.7592
# Epoch 17/100
# 2672/2672 [==============================] - 0s 52us/sample - loss: 6.9264 - mae: 1.9078 - val_loss: 5.9353 - val_mae: 1.7580
# Epoch 18/100
# 2672/2672 [==============================] - 0s 41us/sample - loss: 6.8724 - mae: 1.9115 - val_loss: 5.9028 - val_mae: 1.7574
# Epoch 19/100
# 2672/2672 [==============================] - 0s 50us/sample - loss: 6.8141 - mae: 1.8924 - val_loss: 5.8608 - val_mae: 1.7378
# Epoch 20/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 6.7618 - mae: 1.8896 - val_loss: 5.8304 - val_mae: 1.7386
# Epoch 21/100
# 2672/2672 [==============================] - 0s 44us/sample - loss: 6.7165 - mae: 1.8796 - val_loss: 5.8004 - val_mae: 1.7258
# Epoch 22/100
# 2672/2672 [==============================] - 0s 50us/sample - loss: 6.6737 - mae: 1.8709 - val_loss: 5.7747 - val_mae: 1.7266
# Epoch 23/100
# 2672/2672 [==============================] - 0s 44us/sample - loss: 6.6306 - mae: 1.8768 - val_loss: 5.7528 - val_mae: 1.7333
# Epoch 24/100
# 2672/2672 [==============================] - 0s 41us/sample - loss: 6.5965 - mae: 1.8642 - val_loss: 5.7242 - val_mae: 1.7122
# Epoch 25/100
# 2672/2672 [==============================] - 0s 37us/sample - loss: 6.5519 - mae: 1.8562 - val_loss: 5.7122 - val_mae: 1.7308
# Epoch 26/100
# 2672/2672 [==============================] - 0s 41us/sample - loss: 6.5271 - mae: 1.8624 - val_loss: 5.6815 - val_mae: 1.7255
# Epoch 27/100
# 2672/2672 [==============================] - 0s 43us/sample - loss: 6.4873 - mae: 1.8515 - val_loss: 5.6579 - val_mae: 1.7094
# Epoch 28/100
# 2672/2672 [==============================] - 0s 45us/sample - loss: 6.4567 - mae: 1.8520 - val_loss: 5.6383 - val_mae: 1.7060
# Epoch 29/100
# 2672/2672 [==============================] - 0s 38us/sample - loss: 6.4242 - mae: 1.8373 - val_loss: 5.6166 - val_mae: 1.7134
# Epoch 30/100
# 2672/2672 [==============================] - 0s 41us/sample - loss: 6.3926 - mae: 1.8312 - val_loss: 5.5975 - val_mae: 1.7004
# Epoch 31/100
# 2672/2672 [==============================] - 0s 32us/sample - loss: 6.3653 - mae: 1.8346 - val_loss: 5.5686 - val_mae: 1.6935
# Epoch 32/100
# 2672/2672 [==============================] - 0s 38us/sample - loss: 6.3302 - mae: 1.8300 - val_loss: 5.5587 - val_mae: 1.7078
# Epoch 33/100
# 2672/2672 [==============================] - 0s 36us/sample - loss: 6.3102 - mae: 1.8155 - val_loss: 5.5269 - val_mae: 1.7018
# Epoch 34/100
# 2672/2672 [==============================] - 0s 44us/sample - loss: 6.2700 - mae: 1.8224 - val_loss: 5.5002 - val_mae: 1.6909
# Epoch 35/100
# 2672/2672 [==============================] - 0s 49us/sample - loss: 6.2386 - mae: 1.8317 - val_loss: 5.4732 - val_mae: 1.6910
# Epoch 36/100
# 2672/2672 [==============================] - 0s 48us/sample - loss: 6.2020 - mae: 1.7968 - val_loss: 5.4422 - val_mae: 1.6736
# Epoch 37/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 6.1720 - mae: 1.7954 - val_loss: 5.4242 - val_mae: 1.6807
# Epoch 38/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 6.1380 - mae: 1.8123 - val_loss: 5.3964 - val_mae: 1.6650
# Epoch 39/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 6.1169 - mae: 1.7882 - val_loss: 5.3762 - val_mae: 1.6493
# Epoch 40/100
# 2672/2672 [==============================] - 0s 34us/sample - loss: 6.0785 - mae: 1.7960 - val_loss: 5.3410 - val_mae: 1.6704
# Epoch 41/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 6.0341 - mae: 1.7805 - val_loss: 5.3119 - val_mae: 1.6331
# Epoch 42/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 6.0100 - mae: 1.7680 - val_loss: 5.2998 - val_mae: 1.6757
# Epoch 43/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 5.9726 - mae: 1.7708 - val_loss: 5.2528 - val_mae: 1.6443
# Epoch 44/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 5.9429 - mae: 1.7699 - val_loss: 5.2344 - val_mae: 1.6586
# Epoch 45/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 5.9074 - mae: 1.7443 - val_loss: 5.2144 - val_mae: 1.6612
# Epoch 46/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 5.8798 - mae: 1.7672 - val_loss: 5.1597 - val_mae: 1.6252
# Epoch 47/100
# 2672/2672 [==============================] - 0s 36us/sample - loss: 5.8323 - mae: 1.7579 - val_loss: 5.1309 - val_mae: 1.6256
# Epoch 48/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 5.7977 - mae: 1.7284 - val_loss: 5.1237 - val_mae: 1.6428
# Epoch 49/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 5.7565 - mae: 1.7447 - val_loss: 5.0798 - val_mae: 1.6198
# Epoch 50/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 5.7194 - mae: 1.6986 - val_loss: 5.0749 - val_mae: 1.6476
# Epoch 51/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 5.7081 - mae: 1.7480 - val_loss: 5.0341 - val_mae: 1.5908
# Epoch 52/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 5.6521 - mae: 1.7128 - val_loss: 5.0017 - val_mae: 1.6256
# Epoch 53/100
# 2672/2672 [==============================] - 0s 34us/sample - loss: 5.6213 - mae: 1.7068 - val_loss: 4.9693 - val_mae: 1.6226
# Epoch 54/100
# 2672/2672 [==============================] - 0s 36us/sample - loss: 5.5849 - mae: 1.6927 - val_loss: 4.9565 - val_mae: 1.6275
# Epoch 55/100
# 2672/2672 [==============================] - 0s 36us/sample - loss: 5.5775 - mae: 1.7111 - val_loss: 4.9164 - val_mae: 1.5728
# Epoch 56/100
# 2672/2672 [==============================] - 0s 40us/sample - loss: 5.5184 - mae: 1.7058 - val_loss: 4.8922 - val_mae: 1.5874
# Epoch 57/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 5.4837 - mae: 1.6767 - val_loss: 4.8523 - val_mae: 1.5870
# Epoch 58/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.4487 - mae: 1.6803 - val_loss: 4.8220 - val_mae: 1.5820
# Epoch 59/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 5.4105 - mae: 1.6727 - val_loss: 4.8093 - val_mae: 1.5900
# Epoch 60/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.3904 - mae: 1.6774 - val_loss: 4.7881 - val_mae: 1.5889
# Epoch 61/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.3535 - mae: 1.6700 - val_loss: 4.7759 - val_mae: 1.5470
# Epoch 62/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.3357 - mae: 1.6545 - val_loss: 4.7439 - val_mae: 1.5595
# Epoch 63/100
# 2672/2672 [==============================] - 0s 21us/sample - loss: 5.2920 - mae: 1.6532 - val_loss: 4.7149 - val_mae: 1.5760
# Epoch 64/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 5.2726 - mae: 1.6566 - val_loss: 4.6952 - val_mae: 1.5434
# Epoch 65/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.2463 - mae: 1.6473 - val_loss: 4.6982 - val_mae: 1.5834
# Epoch 66/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.2200 - mae: 1.6385 - val_loss: 4.6495 - val_mae: 1.5425
# Epoch 67/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.2090 - mae: 1.6351 - val_loss: 4.6696 - val_mae: 1.5762
# Epoch 68/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.1911 - mae: 1.6494 - val_loss: 4.6235 - val_mae: 1.5500
# Epoch 69/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 5.1580 - mae: 1.6265 - val_loss: 4.6163 - val_mae: 1.5510
# Epoch 70/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 5.1805 - mae: 1.6395 - val_loss: 4.6345 - val_mae: 1.5769
# Epoch 71/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.1459 - mae: 1.6408 - val_loss: 4.5778 - val_mae: 1.5365
# Epoch 72/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 5.1053 - mae: 1.6236 - val_loss: 4.5952 - val_mae: 1.5221
# Epoch 73/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.0867 - mae: 1.6203 - val_loss: 4.6125 - val_mae: 1.5794
# Epoch 74/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.0878 - mae: 1.6277 - val_loss: 4.5611 - val_mae: 1.5357
# Epoch 75/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.0634 - mae: 1.6255 - val_loss: 4.5632 - val_mae: 1.5201
# Epoch 76/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.0694 - mae: 1.6249 - val_loss: 4.5745 - val_mae: 1.5165
# Epoch 77/100
# 2672/2672 [==============================] - 0s 24us/sample - loss: 5.0711 - mae: 1.6096 - val_loss: 4.5268 - val_mae: 1.5403
# Epoch 78/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 5.0236 - mae: 1.6015 - val_loss: 4.5460 - val_mae: 1.5461
# Epoch 79/100
# 2672/2672 [==============================] - 0s 22us/sample - loss: 5.0170 - mae: 1.6212 - val_loss: 4.5554 - val_mae: 1.5061
# Epoch 80/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 5.0320 - mae: 1.6111 - val_loss: 4.5781 - val_mae: 1.4996
# Epoch 81/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 5.0077 - mae: 1.6062 - val_loss: 4.5259 - val_mae: 1.5356
# Epoch 82/100
# 2672/2672 [==============================] - 0s 25us/sample - loss: 4.9962 - mae: 1.6135 - val_loss: 4.5202 - val_mae: 1.5241
# Epoch 83/100
# 2672/2672 [==============================] - 0s 23us/sample - loss: 4.9901 - mae: 1.6060 - val_loss: 4.5191 - val_mae: 1.5226
# Epoch 84/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 4.9871 - mae: 1.6046 - val_loss: 4.5104 - val_mae: 1.5178
# Epoch 85/100
# 2672/2672 [==============================] - 0s 30us/sample - loss: 4.9916 - mae: 1.6094 - val_loss: 4.5196 - val_mae: 1.5346
# Epoch 86/100
# 2672/2672 [==============================] - 0s 34us/sample - loss: 4.9771 - mae: 1.6017 - val_loss: 4.5218 - val_mae: 1.5106
# Epoch 87/100
# 2672/2672 [==============================] - 0s 35us/sample - loss: 4.9633 - mae: 1.6060 - val_loss: 4.5154 - val_mae: 1.5192
# Epoch 88/100
# 2672/2672 [==============================] - 0s 36us/sample - loss: 4.9608 - mae: 1.6010 - val_loss: 4.5176 - val_mae: 1.5135
# Epoch 89/100
# 2672/2672 [==============================] - 0s 33us/sample - loss: 4.9554 - mae: 1.6067 - val_loss: 4.5217 - val_mae: 1.5142
# Epoch 90/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 4.9851 - mae: 1.6087 - val_loss: 4.5866 - val_mae: 1.4972
# Epoch 91/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 4.9854 - mae: 1.6061 - val_loss: 4.5294 - val_mae: 1.5059
# Epoch 92/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 4.9486 - mae: 1.5962 - val_loss: 4.5073 - val_mae: 1.5317
# Epoch 93/100
# 2672/2672 [==============================] - 0s 26us/sample - loss: 4.9673 - mae: 1.6057 - val_loss: 4.5108 - val_mae: 1.5268
# Epoch 94/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 4.9551 - mae: 1.6084 - val_loss: 4.5124 - val_mae: 1.5222
# Epoch 95/100
# 2672/2672 [==============================] - 0s 29us/sample - loss: 4.9411 - mae: 1.6034 - val_loss: 4.5406 - val_mae: 1.5003
# Epoch 96/100
# 2672/2672 [==============================] - 0s 27us/sample - loss: 4.9497 - mae: 1.5978 - val_loss: 4.5171 - val_mae: 1.5368
# Epoch 97/100
# 2672/2672 [==============================] - 0s 33us/sample - loss: 4.9583 - mae: 1.6010 - val_loss: 4.5445 - val_mae: 1.5626
# Epoch 98/100
# 2672/2672 [==============================] - 0s 33us/sample - loss: 4.9592 - mae: 1.6070 - val_loss: 4.5506 - val_mae: 1.5706
# Epoch 99/100
# 2672/2672 [==============================] - 0s 28us/sample - loss: 4.9617 - mae: 1.6104 - val_loss: 4.5384 - val_mae: 1.5532
# Epoch 100/100
# 2672/2672 [==============================] - 0s 42us/sample - loss: 4.9699 - mae: 1.6118 - val_loss: 4.5171 - val_mae: 1.5378

# %%
y_pred = model.predict(X_te)

# %%
score = model.evaluate(X_te, y_te, batch_size=128)
# Out:
# 836/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
score
# Out:
# [5.1363652995898965, 1.6098971]

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model mse')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation accuracy values
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Model mae')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
